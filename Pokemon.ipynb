# %% [markdown]
# ## Challenge 1: Loading and Exploring the Data
# 1. Load a dataset into a Pandas DataFrame.
# 2. Display the first 10 rows of the dataset.
# 3. Print the column names and their data types.
# 4. Find the total number of rows and columns in the dataset.

# %%
import pandas as pd

df = pd.read_csv('Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Viewing the total number of rows and columns in the dataset
df.shape
print('This data set has {} rows and {} columns'.format(df.shape[0], df.shape[1]))
# Out:
# This data set has 800 rows and 13 columns

# %%
# view columns names
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
#Display the first 10 rows of the dataset
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# ## Challenge 2: Filtering and Selection
# 1. Select only the rows where the Pokémon type is Fire.
# 2. Find all Pokémon with a speed greater than 100.
# 3. Display the names and types of all Pokémon whose total stats are greater than 500.

# %%
#Display Fire Types Pokemons
fire_pokemons = df[df['Type 1']== 'Fire']
fire_pokemons
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
#Pokémon with a speed greater than 100
speedy_pokemons = df[df['Speed'] > 100]
speedy_pokemons
# Out:
#        #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 19    15  BeedrillMega Beedrill       Bug  Poison    495  65     150       40
# 22    18                Pidgeot    Normal  Flying    479  83      80       75
# 23    18    PidgeotMega Pidgeot    Normal  Flying    579  83      80       80
# 31    26                 Raichu  Electric     NaN    485  60      90       55
# 56    51                Dugtrio    Ground     NaN    405  35      80       50
# ..   ...                    ...       ...     ...    ...  ..     ...      ...
# 765  695              Heliolisk  Electric  Normal    481  62      55       52
# 771  701               Hawlucha  Fighting  Flying    500  78      92       75
# 772  702                Dedenne  Electric   Fairy    431  67      58       57
# 791  715                Noivern    Flying  Dragon    535  85      70       80
# 796  719    DiancieMega Diancie      Rock   Fairy    700  50     160      110
#
# ...

# %%
#Display the names and types of all Pokémon whose total stats are greater than 500.

strong_pokemons = df[df['Total']>500]
strong_pokemons_details = strong_pokemons[['Name', 'Type 1', 'Type 2']]
strong_pokemons_details
# Out:
#                           Name   Type 1  Type 2
# 2                     Venusaur    Grass  Poison
# 3        VenusaurMega Venusaur    Grass  Poison
# 6                    Charizard     Fire  Flying
# 7    CharizardMega Charizard X     Fire  Dragon
# 8    CharizardMega Charizard Y     Fire  Flying
# ..                         ...      ...     ...
# 795                    Diancie     Rock   Fairy
# 796        DiancieMega Diancie     Rock   Fairy
# 797        HoopaHoopa Confined  Psychic   Ghost
# 798         HoopaHoopa Unbound  Psychic    Dark
# 799                  Volcanion     Fire   Water
#
# [224 rows x 3 columns]

# %% [markdown]
# ## Challenge 3: Grouping and Aggregation
# 1. Group the Pokémon by their primary type and find the average attack for each type.
# 2. Find the maximum defense stat for each Pokémon type.

# %%
#Group the Pokémon by their primary type and find the average attack for each type.
average_attack_by_type = df.groupby('Type 1')['Attack'].mean()
average_attack_by_type
# Out:
# Type 1
# Bug          70.971014
# Dark         88.387097
# Dragon      112.125000
# Electric     69.090909
# Fairy        61.529412
# Fighting     96.777778
# Fire         84.769231
# Flying       78.750000
# Ghost        73.781250
# Grass        73.214286
# Ground       95.750000
# Ice          72.750000
# Normal       73.469388
# Poison       74.678571
# Psychic      71.456140
# Rock         92.863636
# Steel        92.703704
# Water        74.151786
# Name: Attack, dtype: float64

# %%
# the maximum defense stat for each Pokémon type.
max_defense = df.groupby('Type 1')['Defense'].max()
max_defense
# Out:
# Type 1
# Bug         230
# Dark        125
# Dragon      130
# Electric    115
# Fairy        95
# Fighting     95
# Fire        140
# Flying       80
# Ghost       145
# Grass       131
# Ground      160
# Ice         184
# Normal      126
# Poison      120
# Psychic     160
# Rock        200
# Steel       230
# Water       180
# Name: Defense, dtype: int64

# %%
# Combine average attack and max defense into one DataFrame
stats_by_type = df.groupby('Type 1').agg({'Attack': 'mean', 'Defense': 'max'})

# Rename columns for clarity
stats_by_type = stats_by_type.rename(columns={'Attack': 'Avg Attack', 'Defense': 'Max Defense'})

# Display the combined DataFrame
stats_by_type
# Out:
#           Avg Attack  Max Defense
# Type 1
# Bug        70.971014          230
# Dark       88.387097          125
# Dragon    112.125000          130
# Electric   69.090909          115
# Fairy      61.529412           95
# Fighting   96.777778           95
# Fire       84.769231          140
# Flying     78.750000           80
# Ghost      73.781250          145
# Grass      73.214286          131
# Ground     95.750000          160
# Ice        72.750000          184
# Normal     73.469388          126
# Poison     74.678571          120
# Psychic    71.456140          160
# Rock       92.863636          200
# Steel      92.703704          230
# Water      74.151786          180

# %% [markdown]
# ### Challenge 4: Sorting and Ranking
# 1. Sort the Pokémon by their speed in descending order.
# 2. Rank the Pokémon based on their total stats.

# %%
#Sort the Pokémon by their speed in descending order
fastest_pokemons = df.sort_values(by='Speed', ascending=False)
fastest_pokemons
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 431  386          DeoxysSpeed Forme  Psychic     NaN    600   50      95
# 315  291                    Ninjask      Bug  Flying    456   61      90
# 71    65      AlakazamMega Alakazam  Psychic     NaN    590   55      50
# 429  386         DeoxysAttack Forme  Psychic     NaN    600   50     180
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615   80     135
# ..   ...                        ...      ...     ...    ...  ...     ...
# 486  438                     Bonsly     Rock     NaN    290   50      80
# 658  597                  Ferroseed    Grass   Steel    305   44      50
# 359  328                   Trapinch   Ground     NaN    290   45     100
# 495  446                   Munchlax   Normal     NaN    390  135      85
# 230  213                    Shuckle      Bug    Rock    505   20      10
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Display top 5 fastest Pokémon
print("Top 5 Fastest Pokémon:")
top_5_speedy = fastest_pokemons[['Name', 'Speed']].head()
top_5_speedy
# Out:
# Top 5 Fastest Pokémon:
#                           Name  Speed
# 431          DeoxysSpeed Forme    180
# 315                    Ninjask    160
# 71       AlakazamMega Alakazam    150
# 429         DeoxysAttack Forme    150
# 154  AerodactylMega Aerodactyl    150

# %%
# Ranking by total stats
ranked_by_total = df.sort_values(by='Rank', ascending=False)
ranked_by_total
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 206  191                Sunkern    Grass       NaN    180   30      30
# 322  298                Azurill   Normal     Fairy    190   50      20
# 446  401              Kricketot      Bug       NaN    194   37      25
# 13    10               Caterpie      Bug       NaN    195   45      30
# 16    13                 Weedle      Bug    Poison    195   40      35
# ..   ...                    ...      ...       ...    ...  ...     ...
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary   Rank
# ...

# %%
# Display top 5 Pokémon by total stats
print("Top 5 Pokémon by Total Stats: ")
top_5_rank= ranked_by_total[['Name', 'Rank']].head()
top_5_rank
# Out:
# Top 5 Pokémon by Total Stats:
#           Name   Rank
# 206    Sunkern  800.0
# 322    Azurill  799.0
# 446  Kricketot  798.0
# 13    Caterpie  795.0
# 16      Weedle  795.0

# %% [markdown]
# ## Challenge 5: Handling Missing Data
# 1. Identify if there are any missing values in the dataset.
# 2. Replace any missing values with the column mean or median.

# %%
#Identifying Missing values
print("Missing Data Summary:")
missing_data = df.isnull().sum()
missing_data
# Out:
# Missing Data Summary:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# Rank            0
# dtype: int64

# %%
# Fill missing values in numeric columns with their mean
df_filled_mean = df.copy()  # Make a copy to avoid modifying the original DataFrame
df_filled_mean = df_filled_mean.apply(
    lambda col: col.fillna(col.mean()) if col.dtype in ['float64', 'int64'] else col
)

# Display the updated DataFrame
df_filled_mean.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Rank
# 0       65       65     45           1      False  627.0
# 1       80       80     60           1      False  467.0
# 2      100      100     80           1      False  162.0
# 3      122      120     80           1      False   42.0
# 4       60       50     65           1      False  652.0

# %%
# Fill missing values in numeric columns with their median
df_filled_median = df.copy()  # Make a copy of the DataFrame to avoid modifying the original
df_filled_median = df_filled_median.apply(
    lambda col: col.fillna(col.median()) if col.dtype in ['float64', 'int64'] else col
)

# Display the updated DataFrame
df_filled_median.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Rank
# 0       65       65     45           1      False  627.0
# 1       80       80     60           1      False  467.0
# 2      100      100     80           1      False  162.0
# 3      122      120     80           1      False   42.0
# 4       60       50     65           1      False  652.0

# %%
# Fill missing categorical values with a placeholder
df['Type 2'] = df['Type 2'].fillna('Unknown')

# Display the updated DataFrame
df
# Out:
#        #                   Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass   Poison    318  45      49       49
# 1      2                Ivysaur    Grass   Poison    405  60      62       63
# 2      3               Venusaur    Grass   Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass   Poison    625  80     100      123
# 4      4             Charmander     Fire  Unknown    309  39      52       43
# ..   ...                    ...      ...      ...    ...  ..     ...      ...
# 795  719                Diancie     Rock    Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock    Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic     Dark    680  80     160       60
# 799  721              Volcanion     Fire    Water    600  80     110      120
#
# ...

# %%
# Verify if there are any missing values left in the dataset
missing_values_after = df.isnull().sum()

# Display the result
missing_values_after
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# Rank          0
# dtype: int64

# %% [markdown]
# # Challenge 6: Adding New Columns
# 1. Create a new column called `Power Ratio` as the ratio of attack to defense.
# 2. Add a column called `Is_Legendary` that is `True` if the Pokémon is legendary, otherwise `False`.

# %%
# Add a new column 'Power Ratio' as the ratio of Attack to Defense
df['Power Ratio'] = df['Attack'] / df['Defense']

# Display the DataFrame with the new column
df.head()
# Out:
#    #                   Name Type 1   Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison    318  45      49       49
# 1  2                Ivysaur  Grass   Poison    405  60      62       63
# 2  3               Venusaur  Grass   Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass   Poison    625  80     100      123
# 4  4             Charmander   Fire  Unknown    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Rank  Power Ratio
# 0       65       65     45           1      False  627.0     1.000000
# 1       80       80     60           1      False  467.0     0.984127
# 2      100      100     80           1      False  162.0     0.987952
# 3      122      120     80           1      False   42.0     0.813008
# 4       60       50     65           1      False  652.0     1.209302

# %%
# Ensure the 'Is_Legendary' column exists or is set based on the 'Legendary' column
df['Is_Legendary'] = df['Legendary'] == True

# Display the DataFrame with the new column
df.head()
# Out:
#    #                   Name Type 1   Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison    318  45      49       49
# 1  2                Ivysaur  Grass   Poison    405  60      62       63
# 2  3               Venusaur  Grass   Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass   Poison    625  80     100      123
# 4  4             Charmander   Fire  Unknown    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Rank  Power Ratio  \
# 0       65       65     45           1      False  627.0     1.000000
# 1       80       80     60           1      False  467.0     0.984127
# 2      100      100     80           1      False  162.0     0.987952
# 3      122      120     80           1      False   42.0     0.813008
# 4       60       50     65           1      False  652.0     1.209302
#
#    Is_Legendary
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
# Add a new column 'Total Stats' as the sum of all stat columns
df['Total Stats'] = df[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].sum(axis=1)

# Display the DataFrame with the new column
df.head()
# Out:
#    #                   Name Type 1   Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison    318  45      49       49
# 1  2                Ivysaur  Grass   Poison    405  60      62       63
# 2  3               Venusaur  Grass   Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass   Poison    625  80     100      123
# 4  4             Charmander   Fire  Unknown    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary   Rank  Power Ratio  \
# 0       65       65     45           1      False  627.0     1.000000
# 1       80       80     60           1      False  467.0     0.984127
# 2      100      100     80           1      False  162.0     0.987952
# 3      122      120     80           1      False   42.0     0.813008
# 4       60       50     65           1      False  652.0     1.209302
#
#    Is_Legendary  Total Stats
# 0         False          318
# 1         False          405
# ...

# %% [markdown]
# ## Challenge 7: Advanced Analysis
# 1. Find the Pokémon with the highest combined attack and speed.
# 2. For each type, find the Pokémon with the best defense.

# %%
# Add a column for combined Attack and Speed
df['Attack + Speed'] = df['Attack'] + df['Speed']

# Find the Pokémon with the highest combined Attack and Speed
highest_attack_speed = df.loc[df['Attack + Speed'].idxmax()]

# Display the Pokémon with the highest combined Attack and Speed
highest_attack_speed
# Out:
# #                                386
# Name              DeoxysAttack Forme
# Type 1                       Psychic
# Type 2                       Unknown
# Total                            600
# HP                                50
# Attack                           180
# Defense                           20
# Sp. Atk                          180
# Sp. Def                           20
# Speed                            150
# Generation                         3
# Legendary                       True
# Rank                            49.0
# Power Ratio                      9.0
# Is_Legendary                    True
# Total Stats                      600
# Attack + Speed                   330
# Name: 429, dtype: object

# %%
# Group by 'Type 1' and find the Pokémon with the maximum Defense for each type
best_defense_per_type = df.loc[df.groupby('Type 1')['Defense'].idxmax()]

# Display the DataFrame with the best Defense Pokémon for each type
best_defense_per_type[['Type 1', 'Name', 'Defense']]
# Out:
#        Type 1                     Name  Defense
# 230       Bug                  Shuckle      230
# 327      Dark      SableyeMega Sableye      125
# 409    Dragon  SalamenceMega Salamence      130
# 513  Electric                Magnezone      115
# 519     Fairy                 Togekiss       95
# 256  Fighting                Hitmontop       95
# 355      Fire                  Torkoal      140
# 703    Flying    TornadusTherian Forme       80
# 624     Ghost               Cofagrigus      145
# 659     Grass               Ferrothorn      131
# 424    Ground    GroudonPrimal Groudon      160
# 789       Ice                  Avalugg      184
# 591    Normal        AudinoMega Audino      126
# 118    Poison                  Weezing      120
# 430   Psychic      DeoxysDefense Forme      160
# 414      Rock                 Regirock      200
# 224     Steel      SteelixMega Steelix      230
# 87      Water      SlowbroMega Slowbro      180

# %% [markdown]
# # Challenge 8: Visualization
# 1. Plot a bar chart showing the average HP for each Pokémon type.
# 2. Create a scatter plot of Attack vs. Defense for all Pokémon.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average HP for each Type 1
avg_hp_by_type = df.groupby('Type 1')['HP'].mean().sort_values()

# Plot the bar chart
plt.figure(figsize=(10, 6))
avg_hp_by_type.plot(kind='bar', color='skyblue')
plt.title('Average HP by Pokémon Type', fontsize=14)
plt.xlabel('Type 1', fontsize=12)
plt.ylabel('Average HP', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Scatter plot of Attack vs. Defense
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Attack', y='Defense', hue='Type 1', palette='Set2', alpha=0.8)
plt.title('Attack vs. Defense for Pokémon', fontsize=14)
plt.xlabel('Attack', fontsize=12)
plt.ylabel('Defense', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Type 1')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Challenge 9: Exporting Data
# 1. Save the filtered dataset (e.g., only Pokémon with total stats > 500) to a new CSV file.

# %%
# Provide a valid path to save the file
df.to_csv('C:/Users/kyawz/Desktop/updated_pokemon.csv', index=False)

# Confirm the export
print("Dataset exported successfully!")
# Out:
# Dataset exported successfully!

# %%
import openpyxl
print("openpyxl is installed successfully!")

# Export the DataFrame to an Excel file
df.to_excel('C:/Users/kyawz/Desktop/updated_pokemon.xlsx', index=False)

# Confirm the export
print("Dataset exported to 'updated_pokemon.xlsx'")
# Out:
# openpyxl is installed successfully!
# Dataset exported to 'updated_pokemon.xlsx'

# %%
# Filter Fire-type Pokémon
fire_pokemon = df[df['Type 1'] == 'Fire']

# Export the filtered DataFrame to a CSV file
fire_pokemon.to_csv('C:/Users/kyawz/Desktop/fire_pokemon.csv', index=False)

# Confirm the export
print("Filtered dataset (Fire-type Pokémon) exported to 'fire_pokemon.csv'")
# Out:
# Filtered dataset (Fire-type Pokémon) exported to 'fire_pokemon.csv'

# %%
# Export the DataFrame to a JSON file
df.to_json('C:/Users/kyawz/Desktop/updated_pokemon.json', orient='records', lines=True)

# Confirm the export
print("Dataset exported to 'updated_pokemon.json'")
# Out:
# Dataset exported to 'updated_pokemon.json'
